# %% [markdown]
# # EDBR.1 — reproduce the key figures
#
# Regenerates the dissertation figures **from committed data**
# (`docs/figures/sweep_data.json`, extracted from the sweep artifacts) using
# matplotlib only. The logic lives in `scripts/make_figures.py` so it is testable
# and runnable headless; this notebook is a thin driver.
#
# Run all cells. To rebuild `sweep_data.json` from the live (gitignored)
# `results/` sweeps, run `python scripts/make_figures.py --refresh`.

# %%
import subprocess
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
subprocess.run([sys.executable, str(ROOT / "scripts" / "make_figures.py")], check=True, cwd=ROOT)

# %%
from IPython.display import Image, display

for name in ["collapsed_vs_fixed", "utility_vs_bitrate", "codebook_usage"]:
    display(Image(filename=str(ROOT / "docs" / "figures" / f"{name}.png")))
